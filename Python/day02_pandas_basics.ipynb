# %%
import pandas as pd
import numpy as np

# %%
data = {
    "name": ["Alice", "Bob", "Charlie", "David"],
    "hours": [5, 2, 8, 6],
    "score": [85, 70, 95, 88]
}

df = pd.DataFrame(data)

df
# Out:
#       name  hours  score
# 0    Alice      5     85
# 1      Bob      2     70
# 2  Charlie      8     95
# 3    David      6     88

# %%
print(df.shape)
type(df)
# Out:
# (4, 3)
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#       name  hours  score
# 0    Alice      5     85
# 1      Bob      2     70
# 2  Charlie      8     95
# 3    David      6     88

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   hours   4 non-null      int64
#  2   score   4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
df.describe()
# Out:
#        hours      score
# count   4.00   4.000000
# mean    5.25  84.500000
# std     2.50  10.535654
# min     2.00  70.000000
# 25%     4.25  81.250000
# 50%     5.50  86.500000
# 75%     6.50  89.750000
# max     8.00  95.000000

# %%
df.columns
# Out:
# Index(['name', 'hours', 'score'], dtype='object')

# %%
type(df["score"])
# Out:
# pandas.core.series.Series

# %%
df["score"]
# Out:
# 0    85
# 1    70
# 2    95
# 3    88
# Name: score, dtype: int64

# %%
df["score"][0]
# Out:
# np.int64(85)

# %%
type(df["score"][0])
# Out:
# numpy.int64

# %%
## data selection
print(df.iloc[0]) # select the first row by index
print(df.loc[0]) # select the first row by label
# Out:
# name     Alice
# hours        5
# score       85
# Name: 0, dtype: object
# name     Alice
# hours        5
# score       85
# Name: 0, dtype: object

# %%
df["score"]

df.iloc[:, 2]
# Out:
# 0    85
# 1    70
# 2    95
# 3    88
# Name: score, dtype: int64

# %%
## boolean filtering
## hours >= 5
df[df["hours"] >= 5]
# Out:
#       name  hours  score
# 0    Alice      5     85
# 2  Charlie      8     95
# 3    David      6     88

# %%
## score between 80 and 90
df[(df["score"]<=90) & (df["score"]>=80)]
# Out:
#     name  hours  score
# 0  Alice      5     85
# 3  David      6     88

# %%
## data cleaning
data = {
    "name": ["Alice","Bob","Charlie","David"],
    "hours": [5, None, 8, 6],
    "score": [85,70,None,88]
}

df_missing = pd.DataFrame(data)

df_missing
# Out:
#       name  hours  score
# 0    Alice    5.0   85.0
# 1      Bob    NaN   70.0
# 2  Charlie    8.0    NaN
# 3    David    6.0   88.0

# %%
df_missing.isnull()
# Out:
#     name  hours  score
# 0  False  False  False
# 1  False   True  False
# 2  False  False   True
# 3  False  False  False

# %%
df_missing.dropna()
# Out:
#     name  hours  score
# 0  Alice    5.0   85.0
# 3  David    6.0   88.0

# %%
df_missing["hours"].fillna(
    df_missing["hours"].mean()
)

# %%
df.sort_values("score")
df.sort_values("score",ascending=False)
df.sort_values("score",ascending=False,inplace=True)

# %%
df["score_pct"] = df["score"] / 100
df.shape
# Out:
# (4, 4)
