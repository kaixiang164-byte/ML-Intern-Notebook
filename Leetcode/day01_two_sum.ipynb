# %% [markdown]
# <a href="https://colab.research.google.com/github/kaixiang164-byte/ML-Intern-Notebook/blob/main/Leetcode/two_sum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## leetcode two sum dict

def two_sum_dict_loop(nums, target):
  seen = {}

  for pos,x in enumerate(nums):
    print(pos,x)
    print("current: ", x)
    print("need: ", target - x)
    print("seen: ", seen)

    if (target - x) in seen:
      return [seen[target - x], pos]

    seen[x] = pos

  return []

two_sum_dict_loop(nums = [2,7,11,2,15],target = 4)
# Out:
# 0 2
# current:  2
# need:  2
# seen:  {}
# 1 7
# current:  7
# need:  -3
# seen:  {2: 0}
# 2 11
# current:  11
# need:  -7
# seen:  {2: 0, 7: 1}
# 3 2
# current:  2
# need:  2
# seen:  {2: 0, 7: 1, 11: 2}
# [0, 3]
